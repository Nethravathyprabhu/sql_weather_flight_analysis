# %%
# Import requests package
import requests
import os
import pandas as pd

# %%
# Set URL as url
url = "https://meteostat.p.rapidapi.com/point/daily"

# %%
# To be able to pull the API key from the .env, we need to import and run the load_dotenv function from the dotenv module first.
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
headers = {
    "X-RapidAPI-Host": "meteostat.p.rapidapi.com",
    "X-RapidAPI-key" : os.getenv('x-rapidapi-key')
    }

# %%
# complete the parameter dictionary 
parameters = {
    "lat": "40.6413",    # Latitude of the location(jfk)
    "lon": "-73.7781",   # Longitude of the location
    "start": "2016-01-01",  # Start date
    "end": "2016-01-31",    # End date
    "units": "metric"       # Units of measurement
}

# %%
# Send get request
r = requests.get(url,headers=headers ,params = parameters)

# Print r
r
# Out:
# <Response [403]>

# %%
r.headers
# Out:
# {'Date': 'Fri, 19 Jul 2024 15:34:40 GMT', 'Content-Type': 'application/json', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'X-RapidAPI-Version': '1.2.8', 'X-RapidAPI-Region': 'AWS - eu-central-1', 'X-RapidAPI-Proxy-Response': 'true', 'Server': 'RapidAPI-1.2.8'}

# %%
r.cookies
# Out:
# <RequestsCookieJar[]>

# %%
r.encoding
# Out:
# 'utf-8'

# %%
r.content
# Out:
# b'{"message":"You are not subscribed to this API."}'

# %%
weather_jfk = r.json()
weather_jfk
# Out:
# {'message': 'You are not subscribed to this API.'}

# %%
# Import json package
import json

# Create json object: json_object
json_object = json.loads(r.content)

# Print json_object
json.dumps(json_object, indent = 3)
# Out:
# '{\n   "message": "You are not subscribed to this API."\n}'

# %%
# Loop through and print all key-value pairs
for key, value in weather_jfk.items():
    print( key + ':', value)
# Out:
# message: You are not subscribed to this API.

# %%
weather_jfk
# Out:
# {'message': 'You are not subscribed to this API.'}

# %%
# Print values in meta
print(weather_jfk['meta'])

# Print values in data
print(weather_jfk['data'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 2
#       1 # Print values in meta
# ----> 2 print(weather_jfk['meta'])
#       4 # Print values in data
#       5 print(weather_jfk['data'])
#
# KeyError: 'meta'

# %%
# Print content of json_object
json.dumps(json_object, indent = 3)
# Out:
# '{\n   "meta": {\n      "generated": "2024-07-19 10:24:58",\n      "stations": [\n         "74486",\n         "72502",\n         "KNYC0",\n         "KTEB0"\n      ]\n   },\n   "data": [\n      {\n         "date": "2016-01-01",\n         "tavg": 5.8,\n         "tmin": 2.2,\n         "tmax": 6.7,\n         "prcp": 0.0,\n         "snow": 0.0,\n         "wdir": 283.0,\n         "wspd": 23.4,\n         "wpgt": null,\n         "pres": 1017.3,\n         "tsun": null\n      },\n      {\n         "date": "2016-01-02",\n         "tavg": 3.1,\n         "tmin": 1.1,\n         "tmax": 5.0,\n         "prcp": 0.0,\n         "snow": 0.0,\n         "wdir": 277.0,\n         "wspd": 20.9,\n         "wpgt": null,\n         "pres": 1017.4,\n         "tsun": null\n      },\n      {\n         "date": "2016-01-03",\n         "tavg": 4.6,\n         "tmin": 1.7,\n         "tmax": 8.9,\n         "prcp": 0.0,\n         "snow": 0.0,\n         "wdir": 258.0,\n         "wspd": 22.7,\n         "wpgt": null,\n         "pres": 1011.8,\n         "tsun": null\n      },\n      {\n         "date": "2016-01-04",\n         "tavg": 1.0,\n         "tmin": -9.3,\n         "tmax": 3.3,\n         "prcp": 0.0,\n         "snow": 0.0,\n         "wdir": 333.0,\n         "wspd": 32.0,\n         "wpgt": null,\n         "pres": 1017.7,\n         "tsun": null\n      },\n      {\n         "date": "2016-01-05",\n         "tavg": -7.2,\n         "tmin": -11.0,\n         "tmax": -1.6,\n         "prcp": 0.0,\n         "snow": 0.0,\n         "wdir": 351.0,\n         "wspd": 19.8,\n         "wpgt": null,\n         "pres": 1034.7,\n         "tsun": null\n      },\n      {\n         "date": "2016-01-06",\n         "tavg": -1.4,\n         "tmin": -6.0,\n         "tmax": 4.4,\n         "prcp": 0.0,\n         "snow": 0.0,\n         "wdir": 235.0,\n         "wspd": 12.2,\n         "wpgt": null,\n         "pres": 1034.0,\n         "tsun": null\n      },\n      {\n         "date": "2016-01-07",\n         "tavg": 2.7,\n         "tmin": -2.7,\n         "tmax": 7.8,\n         "prcp": 0.0,\n         "snow": 0.0,\n         "wdir": null,\n         "wspd": 6.1,\n         "wpgt": null,\n         "pres": 1026.3,\n         "tsun": null\n      },\n      {\n         "date": "2016-01-08",\n         "tavg": 4.3,\n         "tmin": 0.0,\n         "tmax": 8.3,\n         "prcp": 0.0,\n         "snow": 0.0,\n         "wdir": 36.0,\n         "wspd": 14.4,\n         "wpgt": null,\n         "pres": 1022.8,\n         "tsun": null\n      },\n      {\n         "date": "2016-01-09",\n         "tavg": 7.2,\n         "tmin": 4.4,\n         "tmax": 11.7,\n         "prcp": 0.5,\n         "snow": 0.0,\n         "wdir": 66.0,\n         "wspd": 18.7,\n         "wpgt": null,\n         "pres": 1021.3,\n         "tsun": null\n      },\n      {\n         "date": "2016-01-10",\n         "tavg": 11.2,\n         "tmin": 5.0,\n         "tmax": 14.4,\n         "prcp": 32.5,\n         "snow": 0.0,\n         "wdir": 152.0,\n         "wspd": 33.8,\n         "wpgt": null,\n         "pres": 1002.2,\n         "tsun": null\n      },\n      {\n         "date": "2016-01-11",\n         "tavg": 3.1,\n         "tmin": -3.2,\n         "tmax": 5.0,\n         "prcp": 0.0,\n         "snow": 0.0,\n         "wdir": 276.0,\n         "wspd": 31.7,\n         "wpgt": null,\n         "pres": 1013.0,\n         "tsun": null\n      },\n      {\n         "date": "2016-01-12",\n         "tavg": 0.4,\n         "tmin": -5.5,\n         "tmax": 7.2,\n         "prcp": 0.0,\n         "snow": 0.0,\n         "wdir": 210.0,\n         "wspd": 22.3,\n         "wpgt": null,\n         "pres": 1012.1,\n         "tsun": null\n      },\n      {\n         "date": "2016-01-13",\n         "tavg": -1.4,\n         "tmin": -4.3,\n         "tmax": -0.5,\n         "prcp": 0.0,\n         "snow": 0.0,\n         "wdir": 277.0,\n         "wspd": 33.5,\n         "wpgt": null,\n         "pres": 1014.4,\n         "tsun": null\n      },\n      {\n         "date": "2016-01-14",\n         "tavg" ...

# %%
# Flatten json and save in weather_jfk_norm
weather_jfk_norm = pd.json_normalize(weather_jfk, sep="_")

# Print weather_hh_norm
weather_jfk_norm
# Out:
#                                                 data       meta_generated  \
# 0  [{'date': '2016-01-01', 'tavg': 5.8, 'tmin': 2...  2024-07-19 10:24:58
#
#                   meta_stations
# 0  [74486, 72502, KNYC0, KTEB0]

# %%
weather_jfk_df = pd.json_normalize(weather_jfk,
                                    sep="_",
                                    record_path="data",
                                    ##meta=[["meta", "generated"], ["meta", "stations"]],
                                    record_prefix="weather_")
weather_jfk_df.head()
# Out:
#   weather_date  weather_tavg  weather_tmin  weather_tmax  weather_prcp  \
# 0   2016-01-01           5.8           2.2           6.7           0.0
# 1   2016-01-02           3.1           1.1           5.0           0.0
# 2   2016-01-03           4.6           1.7           8.9           0.0
# 3   2016-01-04           1.0          -9.3           3.3           0.0
# 4   2016-01-05          -7.2         -11.0          -1.6           0.0
#
#    weather_snow  weather_wdir  weather_wspd weather_wpgt  weather_pres  \
# 0           0.0         283.0          23.4         None        1017.3
# 1           0.0         277.0          20.9         None        1017.4
# 2           0.0         258.0          22.7         None        1011.8
# 3           0.0         333.0          32.0         None        1017.7
# 4           0.0         351.0          19.8         None        1034.7
#
#   weather_tsun
# 0         None
# 1         None
# 2         None
# 3         None
# 4         None

# %%
import time

# %%
# Set the url
url = "https://meteostat.p.rapidapi.com/point/daily" 

# Set lat and lon
#lats  = ["40.6413","40.776863","40.689491","39.8730","38.9523","38.8513"]
#lons = ["-73.7781","-73.8740","-74.1745","-75.2437","-77.4586","-77.0360"]
lats = ["40.776863"]
lons = ["-73.8740"]
start = "2016-01-01"
end   = "2016-01-31"
# Set unit of measurement
unit = "&units=metric"

# Set API key (defined already)
api_key = os.getenv('x-rapidapi-key')
headers = {
    "X-RapidAPI-Host": "meteostat.p.rapidapi.com",
    "X-RapidAPI-key" : os.getenv('x-rapidapi-key')
    }

# Create empty dataframe, will be used to append each location's weather data
weather_df = pd.DataFrame([])

# Loop through all locations
for lat, lon in zip(lats, lons):
    # Create final url
    url_f = url + lat + lon + start + end +  unit + api_key
    print(url_f)
    # Request data from url
    r = requests.get(url_f,headers)
    
    time.sleep(1) #uncomment if you run into a query limit
    
    # Decode repsonse with json decoder
    weather_temp = r.json()

    # Flatten json response
    weather_jfk_df = pd.json_normalize(weather_jfk,
                                       sep="_",
                                       record_path="data",
                                       #meta=[["meta", "generated"], ["meta", "stations"]],
                                       record_prefix="weather_"
                                         )
    # concatenate dataframes
    weather_df = pd.concat([weather_df, weather_temp_df], ignore_index=True)

# Print final dataset weather_df
weather_df
# Out:
# https://meteostat.p.rapidapi.com/point/daily40.776863-73.87402016-01-012016-01-31&units=metriccd067ef5d0msh35ab94cb6bae943p1f6932jsn5c238db36c05
#    weather_date  weather_tavg  weather_tmin  weather_tmax  weather_prcp  \
# 0    2016-01-01           6.7           2.2           8.3           0.0
# 1    2016-01-02           4.2           0.0           8.9           0.0
# 2    2016-01-03           4.9           0.0          12.2           0.0
# 3    2016-01-04           2.0          -6.0           3.3           0.0
# 4    2016-01-05          -4.3          -8.8           1.1           0.0
# 5    2016-01-06          -1.7          -6.6           4.4           0.0
# 6    2016-01-07           3.3           1.1           6.1           0.0
# 7    2016-01-08           5.1           4.4           7.2           0.0
# 8    2016-01-09           6.9           5.0          10.0           5.8
# 9    2016-01-10          12.5           2.8          16.7          14.2
# 10   2016-01-11           2.3          -2.1           5.0           0.0
# 11   2016-01-12           2.1          -2.1           8.3           0.0
# 12   2016-01-13          -2.0          -6.0           0.0           0.0
# 13   2016-01-14           1.7          -2.1          11.7           0.0
# 14   2016-01-15           5.9           1.1          10.0           8.1
# 15   2016-01-16           7.1           3.3          11.7           0.3
# 16   2016-01-17           2.9           0.0           3.3           1.3
# 17   2016-01-18          -3.1          -8.8           1.1           0.0
# 18   2016-01-19          -6.9          -9.3          -2.1           0.0
# 19   2016-01-20          -4.5          -7.1          -0.5           0.8
# 20   2016-01-21          -2.3          -4.3           1.1           0.0
# 21   2016-01-22          -3.3          -5.5          -1.6          13.0
# 22   2016-01-23          -3.7          -4.3          -1.6          24.6
# 23   2016-01-24          -2.1          -7.1           1.7           0.0
# 24   2016-01-25          -2.9          -8.8           5.6           0.0
# 25   2016-01-26           4.1          -1.0          11.1           0.0
# 26   2016-01-27           5.7          -0.5           8.9           0.0
# 27   2016-01-28           0.4          -3.8           4.4           0.0
# 28   2016-01-29           2.4          -2.1           6.1           0.0
# 29   2016-01-30           0.8          -4.3           5.6           0.0
# 30   2016-01-31           6.2           2.2          13.9           0.0
#
#     weather_snow  weather_wdir  weather_wspd weather_wpgt  weather_pres  \
# 0            0.0         317.0          13.3         None        1020.5
# 1            0.0         224.0          10.1         None        1019.4
# 2            0.0         210.0          12.6         None        1013.7
# 3            0.0         338.0          27.0         None        1020.3
# 4            0.0         335.0          16.6         None        1036.5
# 5            0.0         182.0           6.1         None        1034.6
# 6            0.0           NaN           4.3         None        1026.3
# 7            0.0          28.0           7.2         None           NaN
# 8            0.0          24.0           7.6         None        1018.6
# 9            0.0         230.0          27.4         None        1001.7
# 10           0.0         298.0          15.8         None        1017.3
# 11           0.0         210.0          21.6         None        1012.7
# 12           0.0         298.0          16.2         None        1020.1
# 13           0.0         187.0          12.2         None        1015.2
# 14           0.0         176.0           9.4         None        1009.3
# 15           0.0         298.0          14.8         None        1003.8
# 16           0.0         348.0          10.4         None        1010.6
# 17           0.0         296.0          28.4         None        1018.0
# 18           0.0         302.0          24.1         None        1026.2
# 19           0.0         282.0          13.0         None        1025.8
# 20           0.0         307.0          19.4         None        1025.0
# 21           0.0          20.0          18.7         None        1022.9
# 22         360.0         355.0          36.7         None           NaN
# 23         460.0         315.0          14.8         None        1017.6
# 24         430.0           NaN           3.6         None        1024.2
# 25         250.0         202.0          12.6         None        1018.2
# 26         100.0         333.0          15.5         None        1020.4
# 27         100.0           NaN           6.5         None        1014.0
# 28          80.0         280.0          19.4         None        1006.5
# 29          80.0           NaN          12.2         None        1018.4
# 30          80.0         189.0          15.1         None        1013.4
#
#    weather_tsun      lat       lon  faa
# 0          None  38.8513  -77.0360  DCA
# 1          None  38.8513  -77.0360  DCA
# 2          None  38.8513  -77.0360  DCA
# 3          None  38.8513  -77.0360  DCA
# 4          None  38.8513  -77.0360  DCA
# 5          None  38.8513  -77.0360  DCA
# 6          None  38.8513  -77.0360  DCA
# 7          None  38.8513  -77.0360  DCA
# 8          None  38.8513  -77.0360  DCA
# 9          None  38.8513  -77.0360  DCA
# 10         None  38.8513  -77.0360  DCA
# 11         None  38.8513  -77.0360  DCA
# 12         None  38.8513  -77.0360  DCA
# 13         None  38.8513  -77.0360  DCA
# 14         None  38.8513  -77.0360  DCA
# 15         None  38.8513  -77.0360  DCA
# 16         None  38.8513  -77.0360  DCA
# 17         None  38.8513  -77.0360  DCA
# 18         None  38.8513  -77.0360  DCA
# 19         None  38.8513  -77.0360  DCA
# 20         None  38.8513  -77.0360  DCA
# 21         None  38.8513  -77.0360  DCA
# 22         None  38.8513  -77.0360  DCA
# 23         None  38.8513  -77.0360  DCA
# 24         None  38.8513  -77.0360  DCA
# 25         None  38.8513  -77.0360  DCA
# 26         None  38.8513  -77.0360  DCA
# 27         None  38.8513  -77.0360  DCA
# 28         None  38.8513  -77.0360  DCA
# 29         None  38.8513  -77.0360  DCA
# 30         None  38.8513  -77.0360  DCA

# %%
parameters = {
    "lat": "40.6413",    # Latitude of the location(jfk)
    "lon": "-73.7781",   # Longitude of the location
    "start": "2016-01-01",  # Start date
    "end": "2016-01-31",    # End date
    "units": "metric"       # Units of measurement
}

r = requests.get(url,headers=headers ,params = parameters)

# Print r
r
# Out:
# <Response [200]>

# %%
# Set the URL
url = "https://meteostat.p.rapidapi.com/point/daily"

# Set lat and lon
#lats = ["40.776863"]
#lons = ["-73.8740"]
lats  = ["40.6413","40.776863","40.689491","39.8730","38.9523","38.8513"]
lons = ["-73.7781","-73.8740","-74.1745","-75.2437","-77.4586","-77.0360"]
faas = ["JFK","LGA","EWR","PHL","IAD","DCA"]
# Set start and end dates
start = "2016-01-01"
end = "2016-01-31"

# Set unit of measurement
unit = "metric"

# Set API key (defined already)
api_key = os.getenv('x-rapidapi-key')
headers = {
    "X-RapidAPI-Host": "meteostat.p.rapidapi.com",
    "X-RapidAPI-Key": api_key
}

# Create empty dataframe, will be used to append each location's weather data
weather_df = pd.DataFrame([])

# Loop through all locations
for lat, lon , faa in zip(lats, lons,faas):
    # Create final URL
    url_f = f"{url}?lat={lat}&lon={lon}&start={start}&end={end}&units={unit}"
    print(url_f)  # Print the URL for debugging
    
    # Request data from URL
    r = requests.get(url_f, headers=headers)
    
    # Optional: Pause to avoid hitting rate limits
    time.sleep(1) 
    
        # Decode response with json decoder
    weather_temp = r.json()

        # Flatten json response
    weather_temp_df = pd.json_normalize(weather_temp,
                                            sep="_",
                                             record_path="data",
                                                #meta=[["meta", "generated"], ["meta", "stations"]],
                                                record_prefix="weather_"
        )
    weather_temp_df['lat'] = lat
    weather_temp_df['lon'] = lon
    weather_temp_df['faa'] = faa
        # Concatenate dataframes
    weather_df = pd.concat([weather_df, weather_temp_df], ignore_index=True)
        
# Print final dataset weather_df
weather_df.head()
# Out:
# https://meteostat.p.rapidapi.com/point/daily?lat=40.6413&lon=-73.7781&start=2016-01-01&end=2016-01-31&units=metric
# https://meteostat.p.rapidapi.com/point/daily?lat=40.776863&lon=-73.8740&start=2016-01-01&end=2016-01-31&units=metric
# https://meteostat.p.rapidapi.com/point/daily?lat=40.689491&lon=-74.1745&start=2016-01-01&end=2016-01-31&units=metric
# https://meteostat.p.rapidapi.com/point/daily?lat=39.8730&lon=-75.2437&start=2016-01-01&end=2016-01-31&units=metric
# https://meteostat.p.rapidapi.com/point/daily?lat=38.9523&lon=-77.4586&start=2016-01-01&end=2016-01-31&units=metric
# https://meteostat.p.rapidapi.com/point/daily?lat=38.8513&lon=-77.0360&start=2016-01-01&end=2016-01-31&units=metric
#   weather_date  weather_tavg  weather_tmin  weather_tmax  weather_prcp  \
# 0   2016-01-01           5.8           2.2           6.7           0.0
# 1   2016-01-02           3.1           1.1           5.0           0.0
# 2   2016-01-03           4.6           1.7           8.9           0.0
# 3   2016-01-04           1.0          -9.3           3.3           0.0
# 4   2016-01-05          -7.2         -11.0          -1.6           0.0
#
#    weather_snow  weather_wdir  weather_wspd weather_wpgt  weather_pres  \
# 0           0.0         283.0          23.4         None        1017.3
# 1           0.0         277.0          20.9         None        1017.4
# 2           0.0         258.0          22.7         None        1011.8
# 3           0.0         333.0          32.0         None        1017.7
# 4           0.0         351.0          19.8         None        1034.7
#
#   weather_tsun      lat       lon  faa
# 0         None  40.6413  -73.7781  JFK
# 1         None  40.6413  -73.7781  JFK
# 2         None  40.6413  -73.7781  JFK
# 3         None  40.6413  -73.7781  JFK
# 4         None  40.6413  -73.7781  JFK

# %%
weather_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 186 entries, 0 to 185
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   weather_date  186 non-null    object
#  1   weather_tavg  186 non-null    float64
#  2   weather_tmin  186 non-null    float64
#  3   weather_tmax  186 non-null    float64
#  4   weather_prcp  186 non-null    float64
#  5   weather_snow  186 non-null    float64
#  6   weather_wdir  145 non-null    float64
#  7   weather_wspd  186 non-null    float64
#  8   weather_wpgt  0 non-null      object
#  9   weather_pres  183 non-null    float64
#  10  weather_tsun  0 non-null      object
#  11  lat           186 non-null    object
#  12  lon           186 non-null    object
#  13  faa           186 non-null    object
# dtypes: float64(8), object(6)
# memory usage: 20.5+ KB

# %%
weather_df_2 = weather_df.drop(columns = ['lat','lon'])
weather_df_2
# Out:
#     weather_date  weather_tavg  weather_tmin  weather_tmax  weather_prcp  \
# 0     2016-01-01           5.8           2.2           6.7           0.0
# 1     2016-01-02           3.1           1.1           5.0           0.0
# 2     2016-01-03           4.6           1.7           8.9           0.0
# 3     2016-01-04           1.0          -9.3           3.3           0.0
# 4     2016-01-05          -7.2         -11.0          -1.6           0.0
# ..           ...           ...           ...           ...           ...
# 181   2016-01-27           5.7          -0.5           8.9           0.0
# 182   2016-01-28           0.4          -3.8           4.4           0.0
# 183   2016-01-29           2.4          -2.1           6.1           0.0
# 184   2016-01-30           0.8          -4.3           5.6           0.0
# 185   2016-01-31           6.2           2.2          13.9           0.0
#
#      weather_snow  weather_wdir  weather_wspd weather_wpgt  weather_pres  \
# 0             0.0         283.0          23.4         None        1017.3
# 1             0.0         277.0          20.9         None        1017.4
# 2             0.0         258.0          22.7         None        1011.8
# 3             0.0         333.0          32.0         None        1017.7
# 4             0.0         351.0          19.8         None        1034.7
# ..            ...           ...           ...          ...           ...
# 181         100.0         333.0          15.5         None        1020.4
# 182         100.0           NaN           6.5         None        1014.0
# 183          80.0         280.0          19.4         None        1006.5
# 184          80.0           NaN          12.2         None        1018.4
# 185          80.0         189.0          15.1         None        1013.4
#
#     weather_tsun  faa
# 0           None  JFK
# 1           None  JFK
# 2           None  JFK
# 3           None  JFK
# 4           None  JFK
# ..           ...  ...
# 181         None  DCA
# 182         None  DCA
# 183         None  DCA
# 184         None  DCA
# 185         None  DCA
#
# [186 rows x 12 columns]

# %%
weather_df_2.rename(columns = {'faa':'airport'},inplace=True)
weather_df_2
# Out:
#     weather_date  weather_tavg  weather_tmin  weather_tmax  weather_prcp  \
# 0     2016-01-01           5.8           2.2           6.7           0.0
# 1     2016-01-02           3.1           1.1           5.0           0.0
# 2     2016-01-03           4.6           1.7           8.9           0.0
# 3     2016-01-04           1.0          -9.3           3.3           0.0
# 4     2016-01-05          -7.2         -11.0          -1.6           0.0
# ..           ...           ...           ...           ...           ...
# 181   2016-01-27           5.7          -0.5           8.9           0.0
# 182   2016-01-28           0.4          -3.8           4.4           0.0
# 183   2016-01-29           2.4          -2.1           6.1           0.0
# 184   2016-01-30           0.8          -4.3           5.6           0.0
# 185   2016-01-31           6.2           2.2          13.9           0.0
#
#      weather_snow  weather_wdir  weather_wspd weather_wpgt  weather_pres  \
# 0             0.0         283.0          23.4         None        1017.3
# 1             0.0         277.0          20.9         None        1017.4
# 2             0.0         258.0          22.7         None        1011.8
# 3             0.0         333.0          32.0         None        1017.7
# 4             0.0         351.0          19.8         None        1034.7
# ..            ...           ...           ...          ...           ...
# 181         100.0         333.0          15.5         None        1020.4
# 182         100.0           NaN           6.5         None        1014.0
# 183          80.0         280.0          19.4         None        1006.5
# 184          80.0           NaN          12.2         None        1018.4
# 185          80.0         189.0          15.1         None        1013.4
#
#     weather_tsun airport
# 0           None     JFK
# 1           None     JFK
# 2           None     JFK
# 3           None     JFK
# 4           None     JFK
# ..           ...     ...
# 181         None     DCA
# 182         None     DCA
# 183         None     DCA
# 184         None     DCA
# 185         None     DCA
#
# [186 rows x 12 columns]

# %% [markdown]
# task_two_table

# %%
from sql_functions import get_dataframe

# %%
flights_jonas = get_dataframe(f'SELECT * FROM cgn_analytics_24_3.flights_wj201601')

flights_jonas.head()
# Out:
#   flight_date  dep_time  sched_dep_time  dep_delay  arr_time  sched_arr_time  \
# 0  2016-01-01     741.0             745       -4.0    1610.0            1602
# 1  2016-01-02     737.0             745       -8.0    1613.0            1602
# 2  2016-01-03     743.0             745       -2.0    1547.0            1602
# 3  2016-01-04     737.0             745       -8.0    1551.0            1602
# 4  2016-01-05     708.0             710       -2.0    1524.0            1527
#
#    arr_delay airline tail_number  flight_number origin dest  air_time  \
# 0        8.0      AA      N3HMAA             44    SEA  JFK     294.0
# 1       11.0      AA      N3BDAA             44    SEA  JFK     292.0
# 2      -15.0      AA      N3KJAA             44    SEA  JFK     277.0
# 3      -11.0      AA      N3FWAA             44    SEA  JFK     294.0
# 4       -3.0      AA      N3ESAA             44    SEA  JFK     296.0
#
#    actual_elapsed_time  distance  cancelled  diverted
# 0                329.0    2422.0          0         0
# 1                336.0    2422.0          0         0
# 2                304.0    2422.0          0         0
# 3                314.0    2422.0          0         0
# 4                316.0    2422.0          0         0

# %%
df_merged = get_dataframe(f'''SELECT *
FROM cgn_analytics_24_3.flights_wj201601 f
LEFT JOIN cgn_analytics_24_3.airports a
ON f.origin = a.faa''') 

df_merged.head()
# Out:
#   flight_date  dep_time  sched_dep_time  dep_delay  arr_time  sched_arr_time  \
# 0  2016-01-01     741.0             745       -4.0    1610.0            1602
# 1  2016-01-02     737.0             745       -8.0    1613.0            1602
# 2  2016-01-03     743.0             745       -2.0    1547.0            1602
# 3  2016-01-04     737.0             745       -8.0    1551.0            1602
# 4  2016-01-05     708.0             710       -2.0    1524.0            1527
#
#    arr_delay airline tail_number  flight_number  ... diverted  faa  \
# 0        8.0      AA      N3HMAA             44  ...        0  SEA
# 1       11.0      AA      N3BDAA             44  ...        0  SEA
# 2      -15.0      AA      N3KJAA             44  ...        0  SEA
# 3      -11.0      AA      N3FWAA             44  ...        0  SEA
# 4       -3.0      AA      N3ESAA             44  ...        0  SEA
#
#                                    name        lat         lon  alt   tz dst  \
# 0  Seattle Tacoma International Airport  47.449001 -122.308998  433 -8.0   A
# 1  Seattle Tacoma International Airport  47.449001 -122.308998  433 -8.0   A
# 2  Seattle Tacoma International Airport  47.449001 -122.308998  433 -8.0   A
# 3  Seattle Tacoma International Airport  47.449001 -122.308998  433 -8.0   A
# 4  Seattle Tacoma International Airport  47.449001 -122.308998  433 -8.0   A
#
#       city        country
# 0  Seattle  United States
# 1  Seattle  United States
# 2  Seattle  United States
# 3  Seattle  United States
# 4  Seattle  United States
#
# [5 rows x 26 columns]

# %%
df_merged_final = pd.merge(df_merged,weather_df, on ='faa',how= 'inner')
df_merged_final
# Out:
#         flight_date  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0        2016-01-01    1819.0            1825       -6.0    2125.0
# 1        2016-01-01    1819.0            1825       -6.0    2125.0
# 2        2016-01-01    1819.0            1825       -6.0    2125.0
# 3        2016-01-01    1819.0            1825       -6.0    2125.0
# 4        2016-01-01    1819.0            1825       -6.0    2125.0
# ...             ...       ...             ...        ...       ...
# 1216094  2016-01-12       NaN            1159        NaN       NaN
# 1216095  2016-01-12       NaN            1159        NaN       NaN
# 1216096  2016-01-12       NaN            1159        NaN       NaN
# 1216097  2016-01-12       NaN            1159        NaN       NaN
# 1216098  2016-01-12       NaN            1159        NaN       NaN
#
#          sched_arr_time  arr_delay airline tail_number  flight_number  ...  \
# 0                  2150      -25.0      AA      N3MWAA             45  ...
# 1                  2150      -25.0      AA      N3MWAA             45  ...
# 2                  2150      -25.0      AA      N3MWAA             45  ...
# 3                  2150      -25.0      AA      N3MWAA             45  ...
# 4                  2150      -25.0      AA      N3MWAA             45  ...
# ...                 ...        ...     ...         ...            ...  ...
# 1216094            1322        NaN      EV      N13979           6033  ...
# 1216095            1322        NaN      EV      N13979           6033  ...
# 1216096            1322        NaN      EV      N13979           6033  ...
# 1216097            1322        NaN      EV      N13979           6033  ...
# 1216098            1322        NaN      EV      N13979           6033  ...
#
#         weather_tmax weather_prcp  weather_snow  weather_wdir  weather_wspd  \
# 0                6.7          0.0           0.0         283.0          23.4
# 1                5.0          0.0           0.0         277.0          20.9
# 2                8.9          0.0           0.0         258.0          22.7
# 3                3.3          0.0           0.0         333.0          32.0
# 4               -1.6          0.0           0.0         351.0          19.8
# ...              ...          ...           ...           ...           ...
# 1216094          7.2          0.3         360.0         291.0          15.5
# 1216095          5.6          0.0         250.0           NaN           6.5
# 1216096          5.0          0.0         230.0           NaN          16.6
# 1216097          3.9          0.0         200.0         233.0          13.3
# 1216098         12.2          0.0         180.0         202.0           7.9
#
#          weather_wpgt  weather_pres weather_tsun      lat_y     lon_y
# 0                None        1017.3         None    40.6413  -73.7781
# 1                None        1017.4         None    40.6413  -73.7781
# 2                None        1011.8         None    40.6413  -73.7781
# 3                None        1017.7         None    40.6413  -73.7781
# 4                None        1034.7         None    40.6413  -73.7781
# ...               ...           ...          ...        ...       ...
# 1216094          None        1017.0         None  40.689491  -74.1745
# 1216095          None        1013.6         None  40.689491  -74.1745
# 1216096          None        1001.8         None  40.689491  -74.1745
# 1216097          None        1016.4         None  40.689491  -74.1745
# 1216098          None        1012.9         None  40.689491  -74.1745
#
# [1216099 rows x 39 columns]

# %%
df_merged_final = df_merged.join(weather_df_2,how='left')
df_merged_final
# Out:
#       flight_date  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0      2016-01-01     741.0             745       -4.0    1610.0
# 1      2016-01-02     737.0             745       -8.0    1613.0
# 2      2016-01-03     743.0             745       -2.0    1547.0
# 3      2016-01-04     737.0             745       -8.0    1551.0
# 4      2016-01-05     708.0             710       -2.0    1524.0
# ...           ...       ...             ...        ...       ...
# 76940  2016-01-03    1240.0            1250      -10.0    1644.0
# 76941  2016-01-03    1745.0            1745        0.0    2056.0
# 76942  2016-01-03     706.0             650       16.0     901.0
# 76943  2016-01-03    1002.0             940       22.0    1225.0
# 76944  2016-01-03    1728.0            1649       39.0    2241.0
#
#        sched_arr_time  arr_delay airline tail_number  flight_number  ...  \
# 0                1602        8.0      AA      N3HMAA             44  ...
# 1                1602       11.0      AA      N3BDAA             44  ...
# 2                1602      -15.0      AA      N3KJAA             44  ...
# 3                1602      -11.0      AA      N3FWAA             44  ...
# 4                1527       -3.0      AA      N3ESAA             44  ...
# ...               ...        ...     ...         ...            ...  ...
# 76940            1705      -21.0      F9      N925FR           1012  ...
# 76941            2050        6.0      F9      N925FR           1015  ...
# 76942             900        1.0      F9      N932FR           1462  ...
# 76943            1235      -10.0      F9      N932FR           1463  ...
# 76944            2159       42.0      F9      N934FR            720  ...
#
#       weather_tmin weather_tmax  weather_prcp  weather_snow  weather_wdir  \
# 0              2.2          6.7           0.0           0.0         283.0
# 1              1.1          5.0           0.0           0.0         277.0
# 2              1.7          8.9           0.0           0.0         258.0
# 3             -9.3          3.3           0.0           0.0         333.0
# 4            -11.0         -1.6           0.0           0.0         351.0
# ...            ...          ...           ...           ...           ...
# 76940          NaN          NaN           NaN           NaN           NaN
# 76941          NaN          NaN           NaN           NaN           NaN
# 76942          NaN          NaN           NaN           NaN           NaN
# 76943          NaN          NaN           NaN           NaN           NaN
# 76944          NaN          NaN           NaN           NaN           NaN
#
#        weather_wspd  weather_wpgt weather_pres weather_tsun  airport
# 0              23.4          None       1017.3         None      JFK
# 1              20.9          None       1017.4         None      JFK
# 2              22.7          None       1011.8         None      JFK
# 3              32.0          None       1017.7         None      JFK
# 4              19.8          None       1034.7         None      JFK
# ...             ...           ...          ...          ...      ...
# 76940           NaN           NaN          NaN          NaN      NaN
# 76941           NaN           NaN          NaN          NaN      NaN
# 76942           NaN           NaN          NaN          NaN      NaN
# 76943           NaN           NaN          NaN          NaN      NaN
# 76944           NaN           NaN          NaN          NaN      NaN
#
# [76945 rows x 38 columns]

# %%
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76945 entries, 0 to 76944
# Data columns (total 26 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   flight_date          76945 non-null  datetime64[ns]
#  1   dep_time             71033 non-null  float64
#  2   sched_dep_time       76945 non-null  int64
#  3   dep_delay            71033 non-null  float64
#  4   arr_time             70988 non-null  float64
#  5   sched_arr_time       76945 non-null  int64
#  6   arr_delay            70884 non-null  float64
#  7   airline              76945 non-null  object
#  8   tail_number          74181 non-null  object
#  9   flight_number        76945 non-null  int64
#  10  origin               76945 non-null  object
#  11  dest                 76945 non-null  object
#  12  air_time             70884 non-null  float64
#  13  actual_elapsed_time  70884 non-null  float64
#  14  distance             76945 non-null  float64
#  15  cancelled            76945 non-null  int64
#  16  diverted             76945 non-null  int64
#  17  faa                  76945 non-null  object
#  18  name                 76945 non-null  object
#  19  lat                  76945 non-null  float64
#  20  lon                  76945 non-null  float64
#  21  alt                  76945 non-null  int64
#  22  tz                   76945 non-null  float64
#  23  dst                  76945 non-null  object
#  24  city                 76945 non-null  object
#  25  country              76945 non-null  object
# dtypes: datetime64[ns](1), float64(10), int64(6), object(9)
# memory usage: 15.3+ MB
