# %%
# Import requests package
import requests
import os
import pandas as pd

# %%
# Set URL as url
url = "https://meteostat.p.rapidapi.com/point/daily"

# %%
# To be able to pull the API key from the .env, we need to import and run the load_dotenv function from the dotenv module first.
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
headers = {
    "X-RapidAPI-Host": "meteostat.p.rapidapi.com",
    "X-RapidAPI-key" : os.getenv('x-rapidapi-key')
    }

# %%
# complete the parameter dictionary 
parameters = {
    "lat": "40.6413",    # Latitude of the location(jfk)
    "lon": "-73.7781",   # Longitude of the location
    "start": "2016-01-01",  # Start date
    "end": "2016-01-31",    # End date
    "units": "metric"       # Units of measurement
}

# %%
# Send get request
r = requests.get(url,headers=headers ,params = parameters)

# Print r
r
# Out:
# <Response [200]>

# %%
r.headers
# Out:
# {'Date': 'Fri, 19 Jul 2024 11:22:12 GMT', 'Content-Type': 'application/json', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Content-Encoding': 'gzip', 'Cache-Control': 'public, must-revalidate, max-age=259200', 'Last-Modified': 'Fri, 19 Jul 2024 10:24:58 GMT', 'NEL': '{"success_fraction":0,"report_to":"cf-nel","max_age":604800}', 'CF-Cache-Status': 'HIT', 'Vary': 'Accept-Encoding', 'CF-RAY': '8a5a5513cb052d04-FRA', 'X-Meteostat-Server': 'jasper', 'alt-svc': 'h3=":443"; ma=86400', 'Report-To': '{"endpoints":[{"url":"https:\\/\\/a.nel.cloudflare.com\\/report\\/v4?s=1GiwV3vJbl55oIadggw%2BPwYXjryhmBeSI7IrxejyqsIWGcBxA19%2F%2FZxavHUmCgjTG%2B6AkRpULLQcdd8KwOv2zjIJWFJbhci4gMHavKqICm329mkuHonrhpEyYRiP%2BqX7IBHgAVH%2FAQ%3D%3D"}],"group":"cf-nel","max_age":604800}', 'X-RateLimit-Requests-Limit': '500', 'X-RateLimit-Requests-Remaining': '487', 'X-RateLimit-Requests-Reset': '2666248', 'X-RateLimit-rapid-free-plans-hard-limit-Limit': '500000', 'X-RateLimit-rapid-free-plans-hard-limit-Remaining': '499987', 'X-RateLimit-rapid-free-plans-hard-limit-Reset': '2666248', 'Server': 'RapidAPI-1.2.8', 'X-RapidAPI-Version': '1.2.8', 'X-RapidAPI-Region': 'AWS - eu-central-1'}

# %%
r.cookies
# Out:
# <RequestsCookieJar[]>

# %%
r.encoding
# Out:
# 'utf-8'

# %%
r.content
# Out:
# b'{"meta":{"generated": "2024-07-19 10:24:58", "stations": ["74486", "72502", "KNYC0", "KTEB0"]},"data":[{"date":"2016-01-01","tavg":5.8,"tmin":2.2,"tmax":6.7,"prcp":0.0,"snow":0.0,"wdir":283.0,"wspd":23.4,"wpgt":null,"pres":1017.3,"tsun":null},{"date":"2016-01-02","tavg":3.1,"tmin":1.1,"tmax":5.0,"prcp":0.0,"snow":0.0,"wdir":277.0,"wspd":20.9,"wpgt":null,"pres":1017.4,"tsun":null},{"date":"2016-01-03","tavg":4.6,"tmin":1.7,"tmax":8.9,"prcp":0.0,"snow":0.0,"wdir":258.0,"wspd":22.7,"wpgt":null,"pres":1011.8,"tsun":null},{"date":"2016-01-04","tavg":1.0,"tmin":-9.3,"tmax":3.3,"prcp":0.0,"snow":0.0,"wdir":333.0,"wspd":
ow":0.0,"wdir":315.0,"wspd":19.4,"wpgt":null,"pres":1020.9,"tsun":null},{"date":"2016-01-21","tavg":0.4,"tmin":-2.7,"tmax":3.9,"prcp":0.0,"snow":0.0,"wdir":328.0,"wspd":22.0,"wpgt":null,"pres":1020.9,"tsun":null},{"date":"2016-01-22","tavg":-2.6,"tmin":-6.0,"tmax":-1.0,"prcp":0.3,"snow":0.0,"wdir":8.0,"wspd":18.4,"wpgt":null,"pres":1023.9,"tsun":null},{"date":"2016-01-23","tavg":-1.8,"tmin":-3.2,"tmax":-0.5,"prcp":73.7,"snow":180.0,"wdir":27.0,"wspd":40.3,"wpgt":null,"pres":1007.4,"tsun":null},{"date":"2016-01-24","tavg":-2.7,"tmin":-7.1,"tmax":1.7,"prcp":0.0,"snow":710.0,"wdir":328.0,"wspd":20.5,"wpgt":null,"pres":1013.5,"tsun":null},{"date":"2016-01-25","tavg":-0.7,"tmin":-6.6,"tmax":3.9,"prcp":0.0,"snow":660.0,"wdir":null,"wspd":6.8,"wpgt":null,"pres":1024.7,"tsun":null},{"date":"2016-01-26","tavg":3.7,"tmin":1.7,"tmax":7.2,"prcp":0.0,"snow":560.0,"wdir":204.0,"wspd":15.5,"wpgt":null,"pres":1018.1,"tsun":null},{"date":"2016-01-27","tavg":5.9,"tmin":-0.5,"tmax":7.2,"prcp":0.0,"snow":380.0,"wdir":300.0,"wspd":18.4,"wpgt":null,"pres":1017.1,"tsun":null},{"date":"2016-01-28","tavg":1.4,"tmin":-3.8,"tmax":5.6,"prcp":0.0,"snow ...

# %%
weather_jfk = r.json()
weather_jfk
# Out:
# {'meta': {'generated': '2024-07-19 10:24:58',
#   'stations': ['74486', '72502', 'KNYC0', 'KTEB0']},
#  'data': [{'date': '2016-01-01',
#    'tavg': 5.8,
#    'tmin': 2.2,
#    'tmax': 6.7,
#    'prcp': 0.0,
#    'snow': 0.0,
#    'wdir': 283.0,
#    'wspd': 23.4,
#    'wpgt': None,
#    'pres': 1017.3,
#    'tsun': None},
#   {'date': '2016-01-02',
#    'tavg': 3.1,
#    'tmin': 1.1,
#    'tmax': 5.0,
#    'prcp': 0.0,
#    'snow': 0.0,
#    'wdir': 277.0,
#    'wspd': 20.9,
#    'wpgt': None,
#    'pres': 1017.4,
#    'tsun': None},
#   {'date': '2016-01-03',
#    'tavg': 4.6,
#    'tmin': 1.7,
#    'tmax': 8.9,
#    'prcp': 0.0,
#    'snow': 0.0,
#    'wdir': 258.0,
#    'wspd': 22.7,
#    'wpgt': None,
#    'pres': 1011.8,
#    'tsun': None},
#   {'date': '2016-01-04',
#    'tavg': 1.0,
#    'tmin': -9.3,
#    'tmax': 3.3,
#    'prcp': 0.0,
#    'snow': 0.0,
#    'wdir': 333.0,
#    'wspd': 32.0,
#    'wpgt': None,
#    'pres': 1017.7,
#    'tsun': None},
#   {'date': '2016-01-05',
#    'tavg': -7.2,
#    'tmin': -11.0,
#    'tmax': -1.6,
#    'prcp': 0.0,
#    'snow': 0.0,
#    'wdir': 351.0,
#    'wspd': 19.8,
#    'wpgt': None,
#    'pres': 1034.7,
#    'tsun': None},
#   {'date': '2016-01-06',
#    'tavg': -1.4,
#    'tmin': -6.0,
#    'tmax': 4.4,
#    'prcp': 0.0,
#    'snow': 0.0,
#    'wdir': 235.0,
#    'wspd': 12.2,
#    'wpgt': None,
#    'pres': 1034.0,
#    'tsun': None},
#   {'date': '2016-01-07',
#    'tavg': 2.7,
#    'tmin': -2.7,
#    'tmax': 7.8,
#    'prcp': 0.0,
#    'snow': 0.0,
#    'wdir': None,
#    'wspd': 6.1,
#    'wpgt': None,
#    'pres': 1026.3,
#    'tsun': None},
#   {'date': '2016-01-08',
#    'tavg': 4.3,
#    'tmin': 0.0,
#    'tmax': 8.3,
#    'prcp': 0.0,
#    'snow': 0.0,
#    'wdir': 36.0,
#    'wspd': 14.4,
#    'wpgt': None,
#    'pres': 1022.8,
#    'tsun': None},
#   {'date': '2016-01-09',
#    'tavg': 7.2,
#    'tmin': 4.4,
#    'tmax': 11.7,
#    'prcp': 0.5,
#    'snow': 0.0,
#    'wdir': 66.0,
#    'wspd': 18.7,
#    'wpgt': None,
#    'pres': 1021.3,
#    'tsun': None},
#   {'date': '2016-01-10',
#    'tavg': 11.2,
#    'tmin': 5.0,
#    'tmax': 14.4,
#    'prcp': 32.5,
#    'snow': 0.0,
#    'wdir': 152.0,
#    'wspd': 33.8,
#    'wpgt': None,
#    'pres': 1002.2,
#    'tsun': None},
#   {'date': '2016-01-11',
#    'tavg': 3.1,
#    'tmin': -3.2,
#    'tmax': 5.0,
#    'prcp': 0.0,
#    'snow': 0.0,
#    'wdir': 276.0,
#    'wspd': 31.7,
#    'wpgt': None,
#    'pres': 1013.0,
#    'tsun': None},
#   {'date': '2016-01-12',
#    'tavg': 0.4,
#    'tmin': -5.5,
#    'tmax': 7.2,
#    'prcp': 0.0,
#    'snow': 0.0,
#    'wdir': 210.0,
#    'wspd': 22.3,
#    'wpgt': None,
#    'pres': 1012.1,
#    'tsun': None},
#   {'date': '2016-01-13',
#    'tavg': -1.4,
#    'tmin': -4.3,
#    'tmax': -0.5,
#    'prcp': 0.0,
#    'snow': 0.0,
#    'wdir': 277.0,
#    'wspd': 33.5,
#    'wpgt': None,
#    'pres': 1014.4,
#    'tsun': None},
#   {'date': '2016-01-14',
#    'tavg': -1.5,
#    'tmin': -4.3,
#    'tmax': 3.9,
#    'prcp': 0.0,
#    'snow': 0.0,
#    'wdir': 264.0,
#    'wspd': 16.9,
#    'wpgt': None,
#    'pres': 1014.9,
#    'tsun': None},
#   {'date': '2016-01-15',
#    'tavg': 4.6,
#    'tmin': -0.5,
#    'tmax': 10.6,
#    'prcp': 0.0,
#    'snow': 0.0,
#    'wdir': 104.0,
#    'wspd': 11.2,
#    'wpgt': None,
#    'pres': 1010.8,
#    'tsun': None},
#   {'date': '2016-01-16',
#    'tavg': 8.7,
#    'tmin': 6.1,
#    'tmax': 12.2,
#    'prcp': 8.4,
#    'snow': 0.0,
#    'wdir': 312.0,
#    'wspd': 22.0,
#    'wpgt': None,
#    'pres': 1000.3,
#    'tsun': None},
#   {'date': '2016-01-17',
#    'tavg': 3.9,
#    'tmin': -0.5,
#    'tmax': 6.1,
#    'prcp': 1.3,
#    'snow': 0.0,
#    'wdir': 344.0,
#    'wspd': 16.9,
#    'wpgt': None,
#    'pres': 1009.1,
#    'tsun': None},
#   {'date': '2016-01-18',
#    'tavg': -1.8,
#    'tmin': -6.6,
#    'tmax': 0.6,
#    'prcp': 0.0,
#    'snow': 30.0,
#    'wdir': 283.0,
#    'wspd': 34.6,
#    'wpgt': None,
#    'pres': 1010.3,
#    'tsun': None},
#   {'date': '2016-01-19',
#    'tavg': -5.2,
#    'tmin': -7.7,
#    'tmax': -0.5,
#    'prcp': 0.0,
#    'snow': 0.0,
#    'wdir': 290.0,
#    'wspd': 35.3,
#    'wpgt': None,
#    'pres': 1017.2,
#    'tsun': None},
#   {'date': '2016-01-20',
#    'tavg': 0.2,
#    'tmin': -2.1,
#    'tmax': 4.4,
#    'prcp': 0.0,
#    'snow': 0.0,
#    'wdir': 315.0,
#    'wspd': 19.4,
#    'wpgt': None,
#    'pres': 1020.9,
#    'tsun': None},
#   {'date': '2016-01-21',
#    'tavg': 0.4,
#    'tmin': -2.7,
#    'tmax': 3.9,
#    'prcp': 0.0,
#    'snow': 0.0,
#    'wdir': 328.0,
#    'wspd': 22.0,
#    'wpgt': None,
#    'pres': 1020.9,
#    'tsun': None},
#   {'date': '2016-01-22',
#    'tavg': -2.6,
#    'tmin': -6.0,
#    'tmax': -1.0,
#    'prcp': 0.3,
#    'snow': 0.0,
#    'wdir': 8.0,
#    'wspd': 18.4,
#    'wpgt': None,
#    'pres': 1023.9,
#    'tsun': None},
#   {'date': '2016-01-23',
#    'tavg': -1.8,
#    'tmin': -3.2,
#    'tmax': -0.5,
#    'prcp': 73.7,
#    'snow': 180.0,
#    'wdir': 27.0,
#    'wspd': 40.3,
#    'wpgt': None,
#    'pres': 1007.4,
#    'tsun': None},
#   {'date': '2016-01-24',
#    'tavg': -2.7,
#    'tmin': -7.1,
#    'tmax': 1.7,
#    'prcp': 0.0,
#    'snow': 710.0,
#    'wdir': 328.0,
#    'wspd': 20.5,
#    'wpgt': None,
#    'pres': 1013.5,
#    'tsun': None},
#   {'date': '2016-01-25',
#    'tavg': -0.7,
#    'tmin': -6.6,
#    'tmax': 3.9,
#    'prcp': 0.0,
#    'snow': 660.0,
#    'wdir': None,
#    'wspd': 6.8,
#    'wpgt': None,
#    'pres': 1024.7,
#    'tsun': None},
#   {'date': '2016-01-26',
#    'tavg': 3.7,
#    'tmin': 1.7,
#    'tmax': 7.2,
#    'prcp': 0.0,
#    'snow': 560.0,
#    'wdir': 204.0,
#    'wspd': 15.5,
#    'wpgt': None,
#    'pres': 1018.1,
#    'tsun': None},
#   {'date': '2016-01-27',
#    'tavg': 5.9,
#    'tmin': -0.5,
#    'tmax': 7.2,
#    'prcp': 0.0,
#    'snow': 380.0,
#    'wdir': 300.0,
#    'wspd': 18.4,
#    'wpgt': None,
#    'pres': 1017.1,
#    'tsun': None},
#   {'date': '2016-01-28',
#    'tavg': 1.4,
#    'tmin': -3.8,
#    'tmax': 5.6,
#    'prcp': 0.0,
#    'snow': 280.0,
#    'wdir': None,
#    'wspd': 5.8,
#    'wpgt': None,
#    'pres': 1014.0,
#    'tsun': None},
#   {'date': '2016-01-29',
#    'tavg': 3.2,
#    'tmin': -0.5,
#    'tmax': 5.6,
#    'prcp': 0.0,
#    'snow': 230.0,
#    'wdir': 280.0,
#    'wspd': 21.2,
#    'wpgt': None,
#    'pres': 1001.7,
#    'tsun': None},
#   {'date': '2016-01-30',
#    'tavg': 0.8,
#    'tmin': -2.1,
#    'tmax': 3.9,
#    'prcp': 0.0,
#    'snow': 180.0,
#    'wdir': 256.0,
#    'wspd': 18.4,
#    'wpgt': None,
#    'pres': 1016.8,
#    'tsun': None},
#   {'date': '2016-01-31',
#    'tavg': 4.4,
#    'tmin': 0.6,
#    'tmax': 8.9,
#    'prcp': 0.0,
#    'snow': 130.0,
#    'wdir': 200.0,
#    'wspd': 13.7,
#    'wpgt': None,
#    'pres': 1013.7,
#    'tsun': None}]}

# %%
# Import json package
import json

# Create json object: json_object
json_object = json.loads(r.content)

# Print json_object
json.dumps(json_object, indent = 3)
# Out:
# '{\n   "meta": {\n      "generated": "2024-07-19 10:24:58",\n      "stations": [\n         "74486",\n         "72502",\n         "KNYC0",\n         "KTEB0"\n      ]\n   },\n   "data": [\n      {\n         "date": "2016-01-01",\n         "tavg": 5.8,\n         "tmin": 2.2,\n         "tmax": 6.7,\n         "prcp": 0.0,\n         "snow": 0.0,\n         "wdir": 283.0,\n         "wspd": 23.4,\n         "wpgt": null,\n         "pres": 1017.3,\n         "tsun": null\n      },\n      {\n         "date": "2016-01-02",\n         "tavg": 3.1,\n         "tmin": 1.1,\n         "tmax": 5.0,\n         "prcp": 0.0,\n         "snow": 0.0,\n         "wdir": 277.0,\n         "wspd": 20.9,\n         "wpgt": null,\n         "pres": 1017.4,\n         "tsun": null\n      },\n      {\n         "date": "2016-01-03",\n         "tavg": 4.6,\n         "tmin": 1.7,\n         "tmax": 8.9,\n         "prcp": 0.0,\n         "snow": 0.0,\n         "wdir": 258.0,\n         "wspd": 22.7,\n         "wpgt": null,\n         "pres": 1011.8,\n         "tsun": null\n      },\n      {\n         "date": "2016-01-04",\n         "tavg": 1.0,\n         "tmin": -9.3,\n         "tmax": 3.3,\n         "prcp": 0.0,\n         "snow": 0.0,\n         "wdir": 333.0,\n         "wspd": 32.0,\n         "wpgt": null,\n         "pres": 1017.7,\n         "tsun": null\n      },\n      {\n         "date": "2016-01-05",\n         "tavg": -7.2,\n         "tmin": -11.0,\n         "tmax": -1.6,\n         "prcp": 0.0,\n         "snow": 0.0,\n         "wdir": 351.0,\n         "wspd": 19.8,\n         "wpgt": null,\n         "pres": 1034.7,\n         "tsun": null\n      },\n      {\n         "date": "2016-01-06",\n         "tavg": -1.4,\n         "tmin": -6.0,\n         "tmax": 4.4,\n         "prcp": 0.0,\n         "snow": 0.0,\n         "wdir": 235.0,\n         "wspd": 12.2,\n         "wpgt": null,\n         "pres": 1034.0,\n         "tsun": null\n      },\n      {\n         "date": "2016-01-07",\n         "tavg": 2.7,\n         "tmin": -2.7,\n         "tmax": 7.8,\n         "prcp": 0.0,\n         "snow": 0.0,\n         "wdir": null,\n         "wspd": 6.1,\n         "wpgt": null,\n         "pres": 1026.3,\n         "tsun": null\n      },\n      {\n         "date": "2016-01-08",\n         "tavg": 4.3,\n         "tmin": 0.0,\n         "tmax": 8.3,\n         "prcp": 0.0,\n         "snow": 0.0,\n         "wdir": 36.0,\n         "wspd": 14.4,\n         "wpgt": null,\n         "pres": 1022.8,\n         "tsun": null\n      },\n      {\n         "date": "2016-01-09",\n         "tavg": 7.2,\n         "tmin": 4.4,\n         "tmax": 11.7,\n         "prcp": 0.5,\n         "snow": 0.0,\n         "wdir": 66.0,\n         "wspd": 18.7,\n         "wpgt": null,\n         "pres": 1021.3,\n         "tsun": null\n      },\n      {\n         "date": "2016-01-10",\n         "tavg": 11.2,\n         "tmin": 5.0,\n         "tmax": 14.4,\n         "prcp": 32.5,\n         "snow": 0.0,\n         "wdir": 152.0,\n         "wspd": 33.8,\n         "wpgt": null,\n         "pres": 1002.2,\n         "tsun": null\n      },\n      {\n         "date": "2016-01-11",\n         "tavg": 3.1,\n         "tmin": -3.2,\n         "tmax": 5.0,\n         "prcp": 0.0,\n         "snow": 0.0,\n         "wdir": 276.0,\n         "wspd": 31.7,\n         "wpgt": null,\n         "pres": 1013.0,\n         "tsun": null\n      },\n      {\n         "date": "2016-01-12",\n         "tavg": 0.4,\n         "tmin": -5.5,\n         "tmax": 7.2,\n         "prcp": 0.0,\n         "snow": 0.0,\n         "wdir": 210.0,\n         "wspd": 22.3,\n         "wpgt": null,\n         "pres": 1012.1,\n         "tsun": null\n      },\n      {\n         "date": "2016-01-13",\n         "tavg": -1.4,\n         "tmin": -4.3,\n         "tmax": -0.5,\n         "prcp": 0.0,\n         "snow": 0.0,\n         "wdir": 277.0,\n         "wspd": 33.5,\n         "wpgt": null,\n         "pres": 1014.4,\n         "tsun": null\n      },\n      {\n         "date": "2016-01-14",\n         "tavg" ...

# %%
# Loop through and print all key-value pairs
for key, value in weather_jfk.items():
    print( key + ':', value)
# Out:
# meta: {'generated': '2024-07-19 10:24:58', 'stations': ['74486', '72502', 'KNYC0', 'KTEB0']}
, 'pres': 1010.8, 'tsun': None}, {'date': '2016-01-16', 'tavg': 8.7, 'tmin': 6.1, 'tmax': 12.2, 'prcp': 8.4, 'snow': 0.0, 'wdir': 312.0, 'wspd': 22.0, 'wpgt': None, 'pres': 1000.3, 'tsun': None}, {'date': '2016-01-17', 'tavg': 3.9, 'tmin': -0.5, 'tmax': 6.1, 'prcp': 1.3, 'snow': 0.0, 'wdir': 344.0, 'wspd': 16.9, 'wpgt': None, 'pres': 1009.1, 'tsun': None}, {'date': '2016-01-18', 'tavg': -1.8, 'tmin': -6.6, 'tmax': 0.6, 'prcp': 0.0, 'snow': 30.0, 'wdir': 283.0, 'wspd': 34.6, 'wpgt': None, 'pres': 1010.3, 'tsun': None}, {'date': '2016-01-19', 'tavg': -5.2, 'tmin': -7.7, 'tmax': -0.5, 'prcp': 0.0, 'snow': 0.0, 'wdir': 290.0, 'wspd': 35.3, 'wpgt': None, 'pres': 1017.2, 'tsun': None}, {'date': '2016-01-20', 'tavg': 0.2, 'tmin': -2.1, 'tmax': 4.4, 'prcp': 0.0, 'snow': 0.0, 'wdir': 315.0, 'wspd': 19.4, 'wpgt': None, 'pres': 1020.9, 'tsun': None}, {'date': '2016-01-21', 'tavg': 0.4, 'tmin': -2.7, 'tmax': 3.9, 'prcp': 0.0, 'snow': 0.0, 'wdir': 328.0, 'wspd': 22.0, 'wpgt': None, 'pres': 1020.9, 'tsun': None}, {'date': '2016-01-22', 'tavg': -2.6, 'tmin': -6.0, 'tmax': -1.0, 'prcp': 0.3, 'snow': 0.0, 'wdir': 8.0, 'wspd': 18.4, 'wpgt': None, 'pres': 1023.9, 'tsun': None}, {'date': '2016-01-23', 'tavg': -1.8, 'tmin': -3.2, 'tmax': -0.5, 'prcp': 73.7, 'snow': 180.0, 'wdir': 27.0, 'wspd': 40.3, 'wpgt': None, 'pres': 1007.4, 'tsun': None}, {'date': '2016-01-24', 'tavg': -2.7, 'tmin': -7.1, 'tmax': 1.7, 'prcp': 0.0, 'snow': 710.0, 'wdir': 328.0, 'wspd': 20.5, 'wpgt': None, 'pres': 1013.5, 'tsun': None}, {'date': '2016-01-25', 'tavg': -0.7, 'tmin': -6.6, 'tmax': 3.9, 'prc ...

# %%
weather_jfk
# Out:
# {'meta': {'generated': '2024-07-19 10:24:58',
#   'stations': ['74486', '72502', 'KNYC0', 'KTEB0']},
#  'data': [{'date': '2016-01-01',
#    'tavg': 5.8,
#    'tmin': 2.2,
#    'tmax': 6.7,
#    'prcp': 0.0,
#    'snow': 0.0,
#    'wdir': 283.0,
#    'wspd': 23.4,
#    'wpgt': None,
#    'pres': 1017.3,
#    'tsun': None},
#   {'date': '2016-01-02',
#    'tavg': 3.1,
#    'tmin': 1.1,
#    'tmax': 5.0,
#    'prcp': 0.0,
#    'snow': 0.0,
#    'wdir': 277.0,
#    'wspd': 20.9,
#    'wpgt': None,
#    'pres': 1017.4,
#    'tsun': None},
#   {'date': '2016-01-03',
#    'tavg': 4.6,
#    'tmin': 1.7,
#    'tmax': 8.9,
#    'prcp': 0.0,
#    'snow': 0.0,
#    'wdir': 258.0,
#    'wspd': 22.7,
#    'wpgt': None,
#    'pres': 1011.8,
#    'tsun': None},
#   {'date': '2016-01-04',
#    'tavg': 1.0,
#    'tmin': -9.3,
#    'tmax': 3.3,
#    'prcp': 0.0,
#    'snow': 0.0,
#    'wdir': 333.0,
#    'wspd': 32.0,
#    'wpgt': None,
#    'pres': 1017.7,
#    'tsun': None},
#   {'date': '2016-01-05',
#    'tavg': -7.2,
#    'tmin': -11.0,
#    'tmax': -1.6,
#    'prcp': 0.0,
#    'snow': 0.0,
#    'wdir': 351.0,
#    'wspd': 19.8,
#    'wpgt': None,
#    'pres': 1034.7,
#    'tsun': None},
#   {'date': '2016-01-06',
#    'tavg': -1.4,
#    'tmin': -6.0,
#    'tmax': 4.4,
#    'prcp': 0.0,
#    'snow': 0.0,
#    'wdir': 235.0,
#    'wspd': 12.2,
#    'wpgt': None,
#    'pres': 1034.0,
#    'tsun': None},
#   {'date': '2016-01-07',
#    'tavg': 2.7,
#    'tmin': -2.7,
#    'tmax': 7.8,
#    'prcp': 0.0,
#    'snow': 0.0,
#    'wdir': None,
#    'wspd': 6.1,
#    'wpgt': None,
#    'pres': 1026.3,
#    'tsun': None},
#   {'date': '2016-01-08',
#    'tavg': 4.3,
#    'tmin': 0.0,
#    'tmax': 8.3,
#    'prcp': 0.0,
#    'snow': 0.0,
#    'wdir': 36.0,
#    'wspd': 14.4,
#    'wpgt': None,
#    'pres': 1022.8,
#    'tsun': None},
#   {'date': '2016-01-09',
#    'tavg': 7.2,
#    'tmin': 4.4,
#    'tmax': 11.7,
#    'prcp': 0.5,
#    'snow': 0.0,
#    'wdir': 66.0,
#    'wspd': 18.7,
#    'wpgt': None,
#    'pres': 1021.3,
#    'tsun': None},
#   {'date': '2016-01-10',
#    'tavg': 11.2,
#    'tmin': 5.0,
#    'tmax': 14.4,
#    'prcp': 32.5,
#    'snow': 0.0,
#    'wdir': 152.0,
#    'wspd': 33.8,
#    'wpgt': None,
#    'pres': 1002.2,
#    'tsun': None},
#   {'date': '2016-01-11',
#    'tavg': 3.1,
#    'tmin': -3.2,
#    'tmax': 5.0,
#    'prcp': 0.0,
#    'snow': 0.0,
#    'wdir': 276.0,
#    'wspd': 31.7,
#    'wpgt': None,
#    'pres': 1013.0,
#    'tsun': None},
#   {'date': '2016-01-12',
#    'tavg': 0.4,
#    'tmin': -5.5,
#    'tmax': 7.2,
#    'prcp': 0.0,
#    'snow': 0.0,
#    'wdir': 210.0,
#    'wspd': 22.3,
#    'wpgt': None,
#    'pres': 1012.1,
#    'tsun': None},
#   {'date': '2016-01-13',
#    'tavg': -1.4,
#    'tmin': -4.3,
#    'tmax': -0.5,
#    'prcp': 0.0,
#    'snow': 0.0,
#    'wdir': 277.0,
#    'wspd': 33.5,
#    'wpgt': None,
#    'pres': 1014.4,
#    'tsun': None},
#   {'date': '2016-01-14',
#    'tavg': -1.5,
#    'tmin': -4.3,
#    'tmax': 3.9,
#    'prcp': 0.0,
#    'snow': 0.0,
#    'wdir': 264.0,
#    'wspd': 16.9,
#    'wpgt': None,
#    'pres': 1014.9,
#    'tsun': None},
#   {'date': '2016-01-15',
#    'tavg': 4.6,
#    'tmin': -0.5,
#    'tmax': 10.6,
#    'prcp': 0.0,
#    'snow': 0.0,
#    'wdir': 104.0,
#    'wspd': 11.2,
#    'wpgt': None,
#    'pres': 1010.8,
#    'tsun': None},
#   {'date': '2016-01-16',
#    'tavg': 8.7,
#    'tmin': 6.1,
#    'tmax': 12.2,
#    'prcp': 8.4,
#    'snow': 0.0,
#    'wdir': 312.0,
#    'wspd': 22.0,
#    'wpgt': None,
#    'pres': 1000.3,
#    'tsun': None},
#   {'date': '2016-01-17',
#    'tavg': 3.9,
#    'tmin': -0.5,
#    'tmax': 6.1,
#    'prcp': 1.3,
#    'snow': 0.0,
#    'wdir': 344.0,
#    'wspd': 16.9,
#    'wpgt': None,
#    'pres': 1009.1,
#    'tsun': None},
#   {'date': '2016-01-18',
#    'tavg': -1.8,
#    'tmin': -6.6,
#    'tmax': 0.6,
#    'prcp': 0.0,
#    'snow': 30.0,
#    'wdir': 283.0,
#    'wspd': 34.6,
#    'wpgt': None,
#    'pres': 1010.3,
#    'tsun': None},
#   {'date': '2016-01-19',
#    'tavg': -5.2,
#    'tmin': -7.7,
#    'tmax': -0.5,
#    'prcp': 0.0,
#    'snow': 0.0,
#    'wdir': 290.0,
#    'wspd': 35.3,
#    'wpgt': None,
#    'pres': 1017.2,
#    'tsun': None},
#   {'date': '2016-01-20',
#    'tavg': 0.2,
#    'tmin': -2.1,
#    'tmax': 4.4,
#    'prcp': 0.0,
#    'snow': 0.0,
#    'wdir': 315.0,
#    'wspd': 19.4,
#    'wpgt': None,
#    'pres': 1020.9,
#    'tsun': None},
#   {'date': '2016-01-21',
#    'tavg': 0.4,
#    'tmin': -2.7,
#    'tmax': 3.9,
#    'prcp': 0.0,
#    'snow': 0.0,
#    'wdir': 328.0,
#    'wspd': 22.0,
#    'wpgt': None,
#    'pres': 1020.9,
#    'tsun': None},
#   {'date': '2016-01-22',
#    'tavg': -2.6,
#    'tmin': -6.0,
#    'tmax': -1.0,
#    'prcp': 0.3,
#    'snow': 0.0,
#    'wdir': 8.0,
#    'wspd': 18.4,
#    'wpgt': None,
#    'pres': 1023.9,
#    'tsun': None},
#   {'date': '2016-01-23',
#    'tavg': -1.8,
#    'tmin': -3.2,
#    'tmax': -0.5,
#    'prcp': 73.7,
#    'snow': 180.0,
#    'wdir': 27.0,
#    'wspd': 40.3,
#    'wpgt': None,
#    'pres': 1007.4,
#    'tsun': None},
#   {'date': '2016-01-24',
#    'tavg': -2.7,
#    'tmin': -7.1,
#    'tmax': 1.7,
#    'prcp': 0.0,
#    'snow': 710.0,
#    'wdir': 328.0,
#    'wspd': 20.5,
#    'wpgt': None,
#    'pres': 1013.5,
#    'tsun': None},
#   {'date': '2016-01-25',
#    'tavg': -0.7,
#    'tmin': -6.6,
#    'tmax': 3.9,
#    'prcp': 0.0,
#    'snow': 660.0,
#    'wdir': None,
#    'wspd': 6.8,
#    'wpgt': None,
#    'pres': 1024.7,
#    'tsun': None},
#   {'date': '2016-01-26',
#    'tavg': 3.7,
#    'tmin': 1.7,
#    'tmax': 7.2,
#    'prcp': 0.0,
#    'snow': 560.0,
#    'wdir': 204.0,
#    'wspd': 15.5,
#    'wpgt': None,
#    'pres': 1018.1,
#    'tsun': None},
#   {'date': '2016-01-27',
#    'tavg': 5.9,
#    'tmin': -0.5,
#    'tmax': 7.2,
#    'prcp': 0.0,
#    'snow': 380.0,
#    'wdir': 300.0,
#    'wspd': 18.4,
#    'wpgt': None,
#    'pres': 1017.1,
#    'tsun': None},
#   {'date': '2016-01-28',
#    'tavg': 1.4,
#    'tmin': -3.8,
#    'tmax': 5.6,
#    'prcp': 0.0,
#    'snow': 280.0,
#    'wdir': None,
#    'wspd': 5.8,
#    'wpgt': None,
#    'pres': 1014.0,
#    'tsun': None},
#   {'date': '2016-01-29',
#    'tavg': 3.2,
#    'tmin': -0.5,
#    'tmax': 5.6,
#    'prcp': 0.0,
#    'snow': 230.0,
#    'wdir': 280.0,
#    'wspd': 21.2,
#    'wpgt': None,
#    'pres': 1001.7,
#    'tsun': None},
#   {'date': '2016-01-30',
#    'tavg': 0.8,
#    'tmin': -2.1,
#    'tmax': 3.9,
#    'prcp': 0.0,
#    'snow': 180.0,
#    'wdir': 256.0,
#    'wspd': 18.4,
#    'wpgt': None,
#    'pres': 1016.8,
#    'tsun': None},
#   {'date': '2016-01-31',
#    'tavg': 4.4,
#    'tmin': 0.6,
#    'tmax': 8.9,
#    'prcp': 0.0,
#    'snow': 130.0,
#    'wdir': 200.0,
#    'wspd': 13.7,
#    'wpgt': None,
#    'pres': 1013.7,
#    'tsun': None}]}

# %%
# Print values in meta
print(weather_jfk['meta'])

# Print values in data
print(weather_jfk['data'])
# Out:
# {'generated': '2024-07-19 10:24:58', 'stations': ['74486', '72502', 'KNYC0', 'KTEB0']}
# [{'date': '2016-01-01', 'tavg': 5.8, 'tmin': 2.2, 'tmax': 6.7, 'prcp': 0.0, 'snow': 0.0, 'wdir': 283.0, 'wspd': 23.4, 'wpgt': None, 'pres': 1017.3, 'tsun': None}, {'date': '2016-01-02', 'tavg': 3.1, 'tmin': 1.1, 'tmax': 5.0, 'prcp': 0.0, 'snow': 0.0, 'wdir': 277.0, 'wspd': 20.9, 'wpgt': None, 'pres': 1017.4, 'tsun': None}, {'date': '2016-01-03', 'tavg': 4.6, 'tmin': 1.7, 'tmax': 8.9, 'prcp': 0.0, 'snow': 0.0, 'wdir': 258.0, 'wspd': 22.7, 'wpgt': None, 'pres': 1011.8, 'tsun': None}, {'date': '2016-01-04', 'tavg': 1.0, 'tmin': -9.3, 'tmax': 3.3, 'prcp': 0.0, 'snow': 0.0, 'wdir': 333.0, 'wspd': 32.0, 'wpgt': None, 'pres': 1017.7, 'tsun': None}, {'date': '2016-01-05', 'tavg': -7.2, 'tmin': -11.0, 'tmax': -1.6, 'prcp': 0.0, 'snow': 0.0, 'wdir': 351.0, 'wspd': 19.8, 'wpgt': None, 'pres': 1034.7, 'tsun': None}, {'date': '2016-01-06', 'tavg': -1.4, 'tmin': -6.0, 'tmax': 4.4, 'prcp': 0.0, 'snow': 0.0, 'wdir': 235.0, 'wspd': 12.2, 'wpgt': None, 'pres': 1034.0, 'tsun': None}, {'date': '2016-01-07', 'tavg': 2.7, 'tmin': -2.7, 'tmax': 7.8, 'prcp': 0.0, 'snow': 0.0, 'wdir': None, 'wspd': 6.1, 'wpgt': None, 'pres': 1026.3, 'tsun': None}, {'date': '2016-01-08', 'tavg': 4.3, 'tmin': 0.0, 'tmax': 8.3, 'prcp': 0.0, 'snow': 0.0, 'wdir': 36.0, 'wspd': 14.4, 'wpgt': None, 'pres': 1022.8, 'tsun': None}, {'date': '2016-01-09', 'tavg': 7.2, 'tmin': 4.4, 'tmax': 11.7, 'prcp': 0.5, 'snow': 0.0, 'wdir': 66.0, 'wspd': 18.7, 'wpgt': None, 'pres': 1021.3, 'tsun': None}, {'date': '2016-01-10', 'tavg': 11.2, 'tmin': 5.0, 'tmax': 14.4, 'prcp': 32.5, 'snow': 0.0, 'wdir': 152.0, 'wspd': 33.8, 'wpgt': None, 'pres': 1002.2, 'tsun': None}, {'date': '2016-01-11', 'tavg': 3.1, 'tm
# %%
# Print content of json_object
json.dumps(json_object, indent = 3)
# Out:
# '{\n   "meta": {\n      "generated": "2024-07-19 10:24:58",\n      "stations": [\n         "74486",\n         "72502",\n         "KNYC0",\n         "KTEB0"\n      ]\n   },\n   "data": [\n      {\n         "date": "2016-01-01",\n         "tavg": 5.8,\n         "tmin": 2.2,\n         "tmax": 6.7,\n         "prcp": 0.0,\n         "snow": 0.0,\n         "wdir": 283.0,\n         "wspd": 23.4,\n         "wpgt": null,\n         "pres": 1017.3,\n         "tsun": null\n      },\n      {\n         "date": "2016-01-02",\n         "tavg": 3.1,\n         "tmin": 1.1,\n         "tmax": 5.0,\n         "prcp": 0.0,\n         "snow": 0.0,\n         "wdir": 277.0,\n         "wspd": 20.9,\n         "wpgt": null,\n         "pres": 1017.4,\n         "tsun": null\n      },\n      {\n         "date": "2016-01-03",\n         "tavg": 4.6,\n         "tmin": 1.7,\n         "tmax": 8.9,\n         "prcp": 0.0,\n         "snow": 0.0,\n         "wdir": 258.0,\n         "wspd": 22.7,\n         "wpgt": null,\n         "pres": 1011.8,\n         "tsun": null\n      },\n      {\n         "date": "2016-01-04",\n         "tavg": 1.0,\n         "tmin": -9.3,\n         "tmax": 3.3,\n         "prcp": 0.0,\n         "snow": 0.0,\n         "wdir": 333.0,\n         "wspd": 32.0,\n         "wpgt": null,\n         "pres": 1017.7,\n         "tsun": null\n      },\n      {\n         "date": "2016-01-05",\n         "tavg": -7.2,\n         "tmin": -11.0,\n         "tmax": -1.6,\n         "prcp": 0.0,\n         "snow": 0.0,\n         "wdir": 351.0,\n         "wspd": 19.8,\n         "wpgt": null,\n         "pres": 1034.7,\n         "tsun": null\n      },\n      {\n         "date": "2016-01-06",\n         "tavg": -1.4,\n         "tmin": -6.0,\n         "tmax": 4.4,\n         "prcp": 0.0,\n         "snow": 0.0,\n         "wdir": 235.0,\n         "wspd": 12.2,\n         "wpgt": null,\n         "pres": 1034.0,\n         "tsun": null\n      },\n      {\n         "date": "2016-01-07",\n         "tavg": 2.7,\n         "tmin": -2.7,\n         "tmax": 7.8,\n         "prcp": 0.0,\n         "snow": 0.0,\n         "wdir": null,\n         "wspd": 6.1,\n         "wpgt": null,\n         "pres": 1026.3,\n         "tsun": null\n      },\n      {\n         "date": "2016-01-08",\n         "tavg": 4.3,\n         "tmin": 0.0,\n         "tmax": 8.3,\n         "prcp": 0.0,\n         "snow": 0.0,\n         "wdir": 36.0,\n         "wspd": 14.4,\n         "wpgt": null,\n         "pres": 1022.8,\n         "tsun": null\n      },\n      {\n         "date": "2016-01-09",\n         "tavg": 7.2,\n         "tmin": 4.4,\n         "tmax": 11.7,\n         "prcp": 0.5,\n         "snow": 0.0,\n         "wdir": 66.0,\n         "wspd": 18.7,\n         "wpgt": null,\n         "pres": 1021.3,\n         "tsun": null\n      },\n      {\n         "date": "2016-01-10",\n         "tavg": 11.2,\n         "tmin": 5.0,\n         "tmax": 14.4,\n         "prcp": 32.5,\n         "snow": 0.0,\n         "wdir": 152.0,\n         "wspd": 33.8,\n         "wpgt": null,\n         "pres": 1002.2,\n         "tsun": null\n      },\n      {\n         "date": "2016-01-11",\n         "tavg": 3.1,\n         "tmin": -3.2,\n         "tmax": 5.0,\n         "prcp": 0.0,\n         "snow": 0.0,\n         "wdir": 276.0,\n         "wspd": 31.7,\n         "wpgt": null,\n         "pres": 1013.0,\n         "tsun": null\n      },\n      {\n         "date": "2016-01-12",\n         "tavg": 0.4,\n         "tmin": -5.5,\n         "tmax": 7.2,\n         "prcp": 0.0,\n         "snow": 0.0,\n         "wdir": 210.0,\n         "wspd": 22.3,\n         "wpgt": null,\n         "pres": 1012.1,\n         "tsun": null\n      },\n      {\n         "date": "2016-01-13",\n         "tavg": -1.4,\n         "tmin": -4.3,\n         "tmax": -0.5,\n         "prcp": 0.0,\n         "snow": 0.0,\n         "wdir": 277.0,\n         "wspd": 33.5,\n         "wpgt": null,\n         "pres": 1014.4,\n         "tsun": null\n      },\n      {\n         "date": "2016-01-14",\n         "tavg" ...

# %%
# Flatten json and save in weather_jfk_norm
weather_jfk_norm = pd.json_normalize(weather_jfk, sep="_")

# Print weather_hh_norm
weather_jfk_norm
# Out:
#                                                 data       meta_generated  \
# 0  [{'date': '2016-01-01', 'tavg': 5.8, 'tmin': 2...  2024-07-19 10:24:58
#
#                   meta_stations
# 0  [74486, 72502, KNYC0, KTEB0]

# %%
weather_jfk_df = pd.json_normalize(weather_jfk,
                                    sep="_",
                                    record_path="data",
                                    ##meta=[["meta", "generated"], ["meta", "stations"]],
                                    record_prefix="weather_")
weather_jfk_df.head()
# Out:
#   weather_date  weather_tavg  weather_tmin  weather_tmax  weather_prcp  \
# 0   2016-01-01           5.8           2.2           6.7           0.0
# 1   2016-01-02           3.1           1.1           5.0           0.0
# 2   2016-01-03           4.6           1.7           8.9           0.0
# 3   2016-01-04           1.0          -9.3           3.3           0.0
# 4   2016-01-05          -7.2         -11.0          -1.6           0.0
#
#    weather_snow  weather_wdir  weather_wspd weather_wpgt  weather_pres  \
# 0           0.0         283.0          23.4         None        1017.3
# 1           0.0         277.0          20.9         None        1017.4
# 2           0.0         258.0          22.7         None        1011.8
# 3           0.0         333.0          32.0         None        1017.7
# 4           0.0         351.0          19.8         None        1034.7
#
#   weather_tsun
# 0         None
# 1         None
# 2         None
# 3         None
# 4         None

# %%
import time

# %%
# Set the url
url = "https://meteostat.p.rapidapi.com/point/daily" 

# Set lat and lon
#lats  = ["40.6413","40.776863","40.689491","39.8730","38.9523","38.8513"]
#lons = ["-73.7781","-73.8740","-74.1745","-75.2437","-77.4586","-77.0360"]
lats = ["40.776863"]
lons = ["-73.8740"]
start = "2016-01-01"
end   = "2016-01-31"
# Set unit of measurement
unit = "&units=metric"

# Set API key (defined already)
api_key = os.getenv('x-rapidapi-key')
headers = {
    "X-RapidAPI-Host": "meteostat.p.rapidapi.com",
    "X-RapidAPI-key" : os.getenv('x-rapidapi-key')
    }

# Create empty dataframe, will be used to append each location's weather data
weather_df = pd.DataFrame([])

# Loop through all locations
for lat, lon in zip(lats, lons):
    # Create final url
    url_f = url + lat + lon + start + end +  unit + api_key
    print(url_f)
    # Request data from url
    r = requests.get(url_f,headers)
    
    time.sleep(1) #uncomment if you run into a query limit
    
    # Decode repsonse with json decoder
    weather_temp = r.json()

    # Flatten json response
    weather_jfk_df = pd.json_normalize(weather_jfk,
                                       sep="_",
                                       record_path="data",
                                       #meta=[["meta", "generated"], ["meta", "stations"]],
                                       record_prefix="weather_"
                                         )
    # concatenate dataframes
    weather_df = pd.concat([weather_df, weather_temp_df], ignore_index=True)

# Print final dataset weather_df
weather_df
# Out:
# https://meteostat.p.rapidapi.com/point/daily40.776863-73.87402016-01-012016-01-31&units=metriccd067ef5d0msh35ab94cb6bae943p1f6932jsn5c238db36c05
#              message
# 0  Too many requests

# %%
parameters = {
    "lat": "40.6413",    # Latitude of the location(jfk)
    "lon": "-73.7781",   # Longitude of the location
    "start": "2016-01-01",  # Start date
    "end": "2016-01-31",    # End date
    "units": "metric"       # Units of measurement
}

r = requests.get(url,headers=headers ,params = parameters)

# Print r
r

# %%
# Set the URL
url = "https://meteostat.p.rapidapi.com/point/daily"

# Set lat and lon
#lats = ["40.776863"]
#lons = ["-73.8740"]
lats  = ["40.6413","40.776863","40.689491","39.8730","38.9523","38.8513"]
lons = ["-73.7781","-73.8740","-74.1745","-75.2437","-77.4586","-77.0360"]
faas = ["JFK","LGA","EWR","PHL","IAD","DCA"]
# Set start and end dates
start = "2016-01-01"
end = "2016-01-31"

# Set unit of measurement
unit = "metric"

# Set API key (defined already)
api_key = os.getenv('x-rapidapi-key')
headers = {
    "X-RapidAPI-Host": "meteostat.p.rapidapi.com",
    "X-RapidAPI-Key": api_key
}

# Create empty dataframe, will be used to append each location's weather data
weather_df = pd.DataFrame([])

# Loop through all locations
for lat, lon , faa in zip(lats, lons,faas):
    # Create final URL
    url_f = f"{url}?lat={lat}&lon={lon}&start={start}&end={end}&units={unit}"
    print(url_f)  # Print the URL for debugging
    
    # Request data from URL
    r = requests.get(url_f, headers=headers)
    
    # Optional: Pause to avoid hitting rate limits
    time.sleep(1) 
    
        # Decode response with json decoder
    weather_temp = r.json()

        # Flatten json response
    weather_temp_df = pd.json_normalize(weather_temp,
                                            sep="_",
                                             record_path="data",
                                                #meta=[["meta", "generated"], ["meta", "stations"]],
                                                record_prefix="weather_"
        )
    weather_temp_df['lat'] = lat
    weather_temp_df['lon'] = lon
    weather_temp_df['faa'] = faa
        # Concatenate dataframes
    weather_df = pd.concat([weather_df, weather_temp_df], ignore_index=True)
        
# Print final dataset weather_df
weather_df.head()
# Out:
# https://meteostat.p.rapidapi.com/point/daily?lat=40.6413&lon=-73.7781&start=2016-01-01&end=2016-01-31&units=metric
# https://meteostat.p.rapidapi.com/point/daily?lat=40.776863&lon=-73.8740&start=2016-01-01&end=2016-01-31&units=metric
# https://meteostat.p.rapidapi.com/point/daily?lat=40.689491&lon=-74.1745&start=2016-01-01&end=2016-01-31&units=metric
# https://meteostat.p.rapidapi.com/point/daily?lat=39.8730&lon=-75.2437&start=2016-01-01&end=2016-01-31&units=metric
# https://meteostat.p.rapidapi.com/point/daily?lat=38.9523&lon=-77.4586&start=2016-01-01&end=2016-01-31&units=metric
# https://meteostat.p.rapidapi.com/point/daily?lat=38.8513&lon=-77.0360&start=2016-01-01&end=2016-01-31&units=metric
#   weather_date  weather_tavg  weather_tmin  weather_tmax  weather_prcp  \
# 0   2016-01-01           5.8           2.2           6.7           0.0
# 1   2016-01-02           3.1           1.1           5.0           0.0
# 2   2016-01-03           4.6           1.7           8.9           0.0
# 3   2016-01-04           1.0          -9.3           3.3           0.0
# 4   2016-01-05          -7.2         -11.0          -1.6           0.0
#
#    weather_snow  weather_wdir  weather_wspd weather_wpgt  weather_pres  \
# 0           0.0         283.0          23.4         None        1017.3
# 1           0.0         277.0          20.9         None        1017.4
# 2           0.0         258.0          22.7         None        1011.8
# 3           0.0         333.0          32.0         None        1017.7
# 4           0.0         351.0          19.8         None        1034.7
#
#   weather_tsun      lat       lon  faa
# 0         None  40.6413  -73.7781  JFK
# 1         None  40.6413  -73.7781  JFK
# 2         None  40.6413  -73.7781  JFK
# 3         None  40.6413  -73.7781  JFK
# 4         None  40.6413  -73.7781  JFK
